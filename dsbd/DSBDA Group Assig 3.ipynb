# %% [markdown]
# ## Group B - Assignment 3

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Visualize the data using Python libraries matplotlib, seaborn by plotting the graphs for assignment no. 2 (Group B)

# %% [markdown]
# ### Importing python libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Reading data from csv file

# %%
df = pd.read_csv(r"C:\Users\DNYANDEEP\Documents\College\Assignments\DSBDA Lab\airquality.csv")
df
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day Humidity
# 0             1   41.0    190.0   7.4    67      5    1     High
# 1             2   36.0    118.0   8.0    72      5    2     High
# 2             3   12.0    149.0  12.6    74      5    3      Low
# 3             4   18.0    313.0  11.5    62      5    4      NaN
# 4             5    NaN      NaN  14.3    56      5    5     High
# ..          ...    ...      ...   ...   ...    ...  ...      ...
# 148         149   30.0    193.0   6.9    70      9   26      Low
# 149         150    NaN    145.0  13.2    77      9   27      Low
# 150         151   14.0    191.0  14.3    75      9   28     High
# 151         152   18.0    131.0   8.0    76      9   29   Medium
# 152         153   20.0    223.0  11.5    68      9   30      Low
#
# [153 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     0
# Ozone         37
# Solar.R        7
# Wind           2
# Temp           0
# Month          0
# Day            0
# Humidity       8
# dtype: int64

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Removing unwanted columns

# %%
DF = df.drop("Unnamed: 0", axis=1)

# %% [markdown]
# ### Replacing numerical null values

# %%
DF["Ozone"] = DF["Ozone"].fillna(DF["Ozone"].mean())
DF["Solar.R"] = DF["Solar.R"].fillna(DF["Solar.R"].mean())
DF["Wind"] = DF["Wind"].fillna(DF["Wind"].mean())

# %% [markdown]
# ### Replacing categorical null values

# %%
DF["Humidity"] = DF["Humidity"].fillna(DF["Humidity"].mode())
DF.dtypes
# Out:
# Ozone       float64
# Solar.R     float64
# Wind        float64
# Temp          int64
# Month         int64
# Day           int64
# Humidity     object
# dtype: object

# %%
DF.isnull().sum()
# Out:
# Ozone       0
# Solar.R     0
# Wind        0
# Temp        0
# Month       0
# Day         0
# Humidity    8
# dtype: int64

# %% [markdown]
# ## Data Transformation

# %% [markdown]
# ### Using Label Encoding on Humidity column

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
DF["Humidity"] = lb.fit_transform(DF["Humidity"])

# %%
DF["Humidity"].unique()
# Out:
# array([0, 1, 3, 2])

# %%
DF.dtypes
# Out:
# Ozone       float64
# Solar.R     float64
# Wind        float64
# Temp          int64
# Month         int64
# Day           int64
# Humidity      int32
# dtype: object

# %%
DF.head(5)
# Out:
#       Ozone     Solar.R  Wind  Temp  Month  Day  Humidity
# 0  41.00000  190.000000   7.4    67      5    1         0
# 1  36.00000  118.000000   8.0    72      5    2         0
# 2  12.00000  149.000000  12.6    74      5    3         1
# 3  18.00000  313.000000  11.5    62      5    4         3
# 4  42.12931  185.931507  14.3    56      5    5         0

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Pie Chart

# %%
plt.pie([df["Ozone"].mean(),df["Solar.R"].mean(),df["Wind"].mean(),df["Temp"].mean()], autopct="%1.2f%%", 
        explode=[0.01,0.01,0.01,0.01], labels=["Ozone", "Solar.R", "Wind", "Temp"])

plt.plot()
# Out:
# []

# %% [markdown]
# ### Bar Plot

# %%
import seaborn as sns
sns.barplot(df["Month"],df["Temp"])
# Out:
# C:\Users\DNYANDEEP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Month', ylabel='Temp'>

# %% [markdown]
# ### Box Plot

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(x = DF[["Temp", "Solar.R", "Wind", "Ozone"]], labels = ["Temp", "Solar.R", "Wind", "Ozone"])
plt.show()

# %% [markdown]
# ### Line Graph

# %%
X = DF.iloc[1:15, 0] 
Y = DF.iloc[1:15, 3]
plt.plot(X, label="Ozone", marker="o", linestyle="dotted")
plt.plot(Y, label="Temp", marker="o", linestyle="dashed")
plt.title("Line Graph for Ozone and Temp")
plt.legend()
plt.show()

# %% [markdown]
# ###  Histogram

# %%
plt.hist(x=DF["Temp"], bins=20, color="orange", label="Temp")
plt.title("Temperature count")
plt.xlabel("Temperature")
plt.ylabel("Count")
plt.plot()
# Out:
# []

# %% [markdown]
# ### Scatter Plot

# %%
plt.scatter(x = DF["Ozone"],y = DF["Temp"])
plt.legend(["Ozone"])
plt.xlabel("Ozone")
plt.ylabel("Temp")
plt.title("Ozone Scatter Plot")
plt.show()

# %% [markdown]
# ### Pair Plot

# %%
import seaborn as sns
sns.pairplot(df.iloc[:,[1,2,3,4,7]], hue ='Humidity')
plt.show()

# %% [markdown]
# ### Heat Map

# %%
corr = DF.corr()
sns.heatmap(corr, annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Word Cloud

# %%
from wordcloud import WordCloud, STOPWORDS
text = """Python is an interpreted, object-oriented, high-level programming language with
Its high-level built in data structures, combined with dynamic typing and dynamic binding
make it very attractive for Rapid Application Development, 
as well as for use as a scripting or glue language to connect existing components together"""

wrd_cld = WordCloud(background_color="white", height=2225, width=4450).generate(text)
plt.imshow(wrd_cld)
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28404\16819879.py in <module>
# ----> 1 from wordcloud import WordCloud, STOPWORDS
#       2 text = """Python is an interpreted, object-oriented, high-level programming language with
#       3 Its high-level built in data structures, combined with dynamic typing and dynamic binding
#       4 make it very attractive for Rapid Application Development,
#       5 as well as for use as a scripting or glue language to connect existing components together"""
#
# ModuleNotFoundError: No module named 'wordcloud'
