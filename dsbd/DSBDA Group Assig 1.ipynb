# %% [markdown]
# ## Group B - Assignment 1

# %% [markdown]
# ### Problem Statement

# %% [markdown]
# Perform the following operations using Python on the Facebook metrics data sets.

# %% [markdown]
# a. Create data subsets ¶
#
# b. Merge Data
#
# c. Sort Data
#
# d. Transposing Data
#
# e. Shape and reshape Data

# %% [markdown]
# ### IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Reading data from CSV file

# %%
df = pd.read_csv(r"C:\Users\DNYANDEEP\Documents\College\Assignments\DSBDA Lab\dataset_Facebook1.csv", sep = ";")
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.shape
# Out:
# (500, 19)

# %% [markdown]
# ### Creating Subset

# %% [markdown]
# #### a. Row Wise

# %%
# Subset - 1
df1 = df.iloc[[1,9,20,25,30,36,45,60,70,88],:]
df1
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1             139441  Status         2          12             3         10
# 9             139441   Photo         3          12             6         10
# 20            138414   Photo         2          12             1          3
# 25            138458  Status         2          12             6          3
# 30            138895   Photo         2          12             4          2
# 36            138895   Photo         3          12             1          3
# 45            138353    Link         1          12             4          3
# 60            138185   Photo         1          11             3         11
# 70            137893   Photo         1          11             5         10
# 88            137177   Photo         1          11             3          3
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# ...

# %%
df1.shape
# Out:
# (10, 19)

# %%
#Subset - 2
df2 = df.iloc[[91,155,167,199,235,301,367,444,480,492],:]
df2
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 91             137059   Photo         2          11             1          9
# 155            135700   Photo         2           9             3          7
# 167            135428   Photo         3           9             4          2
# 199            132817   Photo         3           8             4         10
# 235            131300  Status         2           7             7         10
# 301            124940   Photo         3           6             6          2
# 367            115368   Photo         3           4             2          2
# 444             96749   Photo         2           3             2          5
# 480             86909   Photo         2           1             4         11
# 492             85979    Link         1           1             5         11
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# ...

# %%
df2.shape
# Out:
# (10, 19)

# %% [markdown]
# ### Merging the row-wise subsets

# %%
m1 = pd.concat([df1, df2])
m1
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1              139441  Status         2          12             3         10
# 9              139441   Photo         3          12             6         10
# 20             138414   Photo         2          12             1          3
# 25             138458  Status         2          12             6          3
# 30             138895   Photo         2          12             4          2
# 36             138895   Photo         3          12             1          3
# 45             138353    Link         1          12             4          3
# 60             138185   Photo         1          11             3         11
# 70             137893   Photo         1          11             5         10
# 88             137177   Photo         1          11             3          3
# 91             137059   Photo         2          11             1          9
# ...

# %% [markdown]
# #### b. Column Wise

# %%
#Subset - 3
df3 = df.iloc[:,[1,2,5,6]]
df3
# Out:
#        Type  Category  Post Hour  Paid
# 0     Photo         2          3   0.0
# 1    Status         2         10   0.0
# 2     Photo         3          3   0.0
# 3     Photo         2         10   1.0
# 4     Photo         2          3   0.0
# ..      ...       ...        ...   ...
# 495   Photo         3          2   0.0
# 496   Photo         2          8   0.0
# 497   Photo         1          2   0.0
# 498   Photo         3         11   0.0
# 499   Photo         2          4   NaN
#
# [500 rows x 4 columns]

# %%
#Subset - 4
df4 = df.iloc[:, [16,17,18]]
df4
# Out:
#        like  share  Total Interactions
# 0      79.0   17.0                 100
# 1     130.0   29.0                 164
# 2      66.0   14.0                  80
# 3    1572.0  147.0                1777
# 4     325.0   49.0                 393
# ..      ...    ...                 ...
# 495    53.0   26.0                  84
# 496    53.0   22.0                  75
# 497    93.0   18.0                 115
# 498    91.0   38.0                 136
# 499    91.0   28.0                 119
#
# [500 rows x 3 columns]

# %% [markdown]
# ### Merge Column-wise subsets

# %%
m2 = df3.merge(df4, left_index=True, right_index=True)
m2
# Out:
#        Type  Category  Post Hour  Paid    like  share  Total Interactions
# 0     Photo         2          3   0.0    79.0   17.0                 100
# 1    Status         2         10   0.0   130.0   29.0                 164
# 2     Photo         3          3   0.0    66.0   14.0                  80
# 3     Photo         2         10   1.0  1572.0  147.0                1777
# 4     Photo         2          3   0.0   325.0   49.0                 393
# ..      ...       ...        ...   ...     ...    ...                 ...
# 495   Photo         3          2   0.0    53.0   26.0                  84
# 496   Photo         2          8   0.0    53.0   22.0                  75
# 497   Photo         1          2   0.0    93.0   18.0                 115
# 498   Photo         3         11   0.0    91.0   38.0                 136
# 499   Photo         2          4   NaN    91.0   28.0                 119
#
# [500 rows x 7 columns]

# %% [markdown]
# ### Sort Values

# %% [markdown]
# #### a. Descending Order

# %%
sort_values = df.sort_values('Post Hour', ascending=False)
sort_values
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 230            131630  Photo         3           7             2         23
# 287            126141  Photo         1           6             4         22
# 381            109670  Photo         3           4             6         20
# 422            102112  Photo         1           3             1         19
# 424            102112  Photo         1           3             1         18
# ..                ...    ...       ...         ...           ...        ...
# 157            135700  Photo         3           9             2          2
# 212            132201  Photo         2           8             5          1
# 258            129600  Photo         2           7             3          1
# 333            119198  Photo         3           5             2          1
# 154            135713  Photo         2          10             4          1
#
# ...

# %% [markdown]
# #### b. Ascending Order

# %%
sort_values = df.sort_values('Post Hour', ascending=True)
sort_values
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 154            135713  Photo         2          10             4          1
# 333            119198  Photo         3           5             2          1
# 212            132201  Photo         2           8             5          1
# 258            129600  Photo         2           7             3          1
# 346            117764  Photo         3           5             7          2
# ..                ...    ...       ...         ...           ...        ...
# 426            100732  Photo         1           3             7         18
# 422            102112  Photo         1           3             1         19
# 381            109670  Photo         3           4             6         20
# 287            126141  Photo         1           6             4         22
# 230            131630  Photo         3           7             2         23
#
# ...

# %% [markdown]
# ### Transpose of Dataset

# %%
df.transpose()
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %% [markdown]
# ### Reshaping the Dataset

# %%
reshape = df.melt(id_vars=["like"], value_vars=["Category", "share", "comment"])
reshape
# Out:
#         like  variable  value
# 0       79.0  Category    2.0
# 1      130.0  Category    2.0
# 2       66.0  Category    3.0
# 3     1572.0  Category    2.0
# 4      325.0  Category    2.0
# ...      ...       ...    ...
# 1495    53.0   comment    5.0
# 1496    53.0   comment    0.0
# 1497    93.0   comment    4.0
# 1498    91.0   comment    7.0
# 1499    91.0   comment    0.0
#
# [1500 rows x 3 columns]

# %%
reshape1 = pd.melt(df, id_vars='like', value_name= 'Page Total Likes')
reshape1
# Out:
#         like            variable Page Total Likes
# 0       79.0    Page total likes           139441
# 1      130.0    Page total likes           139441
# 2       66.0    Page total likes           139441
# 3     1572.0    Page total likes           139441
# 4      325.0    Page total likes           139441
# ...      ...                 ...              ...
# 8995    53.0  Total Interactions               84
# 8996    53.0  Total Interactions               75
# 8997    93.0  Total Interactions              115
# 8998    91.0  Total Interactions              136
# 8999    91.0  Total Interactions              119
#
# [9000 rows x 3 columns]

# %%
reshape2 = pd.melt(df, id_vars='like', value_vars= ["Category", "share", "comment"])
reshape2
# Out:
#         like  variable  value
# 0       79.0  Category    2.0
# 1      130.0  Category    2.0
# 2       66.0  Category    3.0
# 3     1572.0  Category    2.0
# 4      325.0  Category    2.0
# ...      ...       ...    ...
# 1495    53.0   comment    5.0
# 1496    53.0   comment    0.0
# 1497    93.0   comment    4.0
# 1498    91.0   comment    7.0
# 1499    91.0   comment    0.0
#
# [1500 rows x 3 columns]
